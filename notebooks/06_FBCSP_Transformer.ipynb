# %%
import numpy as np
import mne
from mne.decoding import CSP
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier  # Neural Network Classifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, cross_val_predict, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from mne.filter import filter_data
import matplotlib.pyplot as plt
# Import the required Python libraries
import os
import re
from pathlib import Path
import pandas as pd
import numpy as np
import mne
from mne import Epochs

# %%
# Define the path to your raw_data directory
data_dir = Path('../data/raw data')  # Adjust this path as needed

# Verify the directory exists
if not data_dir.exists():
    raise FileNotFoundError(f"The specified data directory does not exist: {data_dir}")

# Define the specific runs to process, including both two-digit and three-digit run numbers
desired_runs = ['04', '08', '12']

# Compile a regular expression pattern to match filenames like S001R04.edf, S002R08.edf, S001R012.edf, etc.
# This pattern ensures that only R04, R08, R12 are matched
edf_pattern = re.compile(r'^S\d{3}R0?(04|08|12)\.edf$', re.IGNORECASE)

# %%
# Initialize a list to store file information
file_info = []

# Counter for processed subject directories
processed_subjects = 0

# Iterate through each subject folder in raw_data
for subject_dir in data_dir.iterdir():
    if subject_dir.is_dir() and re.match(r'^S\d{3}$', subject_dir.name, re.IGNORECASE):
        processed_subjects += 1
        # Iterate through each file in the subject directory
        for file in subject_dir.iterdir():
            if file.is_file() and edf_pattern.match(file.name):
                # Derive the corresponding event file name
                base_name = file.stem  # e.g., S001R04
                event_file = f"{base_name}.edf.event"
                event_path = subject_dir / event_file
                
                # Check if the event file exists
                event_exists = event_path.exists()
                
                # Append the information to the list
                file_info.append({
                    'subject': subject_dir.name,
                    'edf_file': file.name,
                    'event_file': event_file,
                    'event_exists': event_exists,
                    'edf_path': str(file.resolve()),
                    'event_path': str(event_path.resolve()) if event_exists else None
                })

# Convert the list to a DataFrame for better visualization
df_files = pd.DataFrame(file_info)

# Display summary of processed subject directories
print(f"Total subject directories processed: {processed_subjects}")
# Out:
# Total subject directories processed: 109

# %%
# Total number of matched .edf files
total_edf = df_files.shape[0]

# Number of event files present
total_events = df_files['event_exists'].sum()

# Number of missing event files
missing_events = total_edf - total_events

print(f"Total matched .edf files: {total_edf}")
print(f"Number of corresponding event files found: {total_events}")
print(f"Number of missing event files: {missing_events}")

# %%
# Filter the DataFrame for missing event files
df_missing_events = df_files[~df_files['event_exists']]

# Display the list of .edf files without corresponding event files
if not df_missing_events.empty:
    print("\nFiles missing corresponding event files:")
    display(df_missing_events[['subject', 'edf_file', 'event_file']])
else:
    print("\nAll matched .edf files have corresponding event files.")
# Out:
# All matched .edf files have corresponding event files.

# %%
# Display the entire DataFrame of matched files
print("List of All Matched .edf Files:")
display(df_files[['subject', 'edf_file', 'event_file', 'event_exists']])
# Out:
# List of All Matched .edf Files:
#     subject     edf_file         event_file  event_exists
# 0      S038  S038R12.edf  S038R12.edf.event          True
# 1      S038  S038R04.edf  S038R04.edf.event          True
# 2      S038  S038R08.edf  S038R08.edf.event          True
# 3      S007  S007R08.edf  S007R08.edf.event          True
# 4      S007  S007R04.edf  S007R04.edf.event          True
# ..      ...          ...                ...           ...
# 322    S106  S106R04.edf  S106R04.edf.event          True
# 323    S106  S106R08.edf  S106R08.edf.event          True
# 324    S108  S108R04.edf  S108R04.edf.event          True
# 325    S108  S108R12.edf  S108R12.edf.event          True
# 326    S108  S108R08.edf  S108R08.edf.event          True
#
# [327 rows x 4 columns]

# %%
# Initialize lists to collect data and labels from all files
X_all = []
y_all = []

# %%
# Define desired event types
desired_event_types = ['Rest', 'Imagining Left Hand', 'Imagining Right Hand']

# Iterate through each matched EDF file
for idx, row in df_files.iterrows():
    edf_path = row['edf_path']
    event_exists = row['event_exists']
    subject = row['subject']
    edf_file = row['edf_file']
    
    print(f"\nProcessing file: {edf_file} for subject: {subject}")
    
    if not event_exists:
        print(f"Skipping {edf_file} as it lacks an event file.")
        continue
    
    try:
        # Load the raw EEG data

        raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
        # Convert annotations to events and event_id
        events, event_id = mne.events_from_annotations(raw) # This line is missing in your code

        # Define event dictionary
        event_dict = {
            'T0': 1,                # Resting State
            'T1': 2,  # 'Imagining Left Hand': 
            'T2': 3  # 'Imagining Right Hand':
        }



        # Update event_id with descriptive labels
        event_id = {
            'T0': 1,
            'T1': 2,
            'T2': 3
        }

        
        # Access annotations
        annotations = raw.annotations
        
        # Define epoch parameters
        tmin = -0.2  # 200 ms before the event
        tmax = 3.8   # 3800 ms after the event
        baseline = (None, 0)  # Baseline correction
        
        # Convert annotations to events
        events, _ = mne.events_from_annotations(raw, event_id=event_dict)
        
        if events.size == 0:
            print(f"No events found in {edf_file}. Skipping.")
            continue
        
        # Create epochs
        epochs = Epochs(raw, events, event_id=event_dict, tmin=tmin, tmax=tmax, baseline=baseline, preload=True, verbose=False)
        
        # Select only 'Imagining Left Hand' and 'Imagining Right Hand' epochs
        motor_epochs = epochs[['T1', 'T2']]
        
        if len(motor_epochs) == 0:
            print(f"No motor-related epochs found in {edf_file}. Skipping.")
            continue
        
        # Extract labels: 0 for Left, 1 for Right
        labels = motor_epochs.events[:, -1] - event_dict['T1']
        
        # Get the data as a NumPy array: shape (n_epochs, n_channels, n_times)
        X = motor_epochs.get_data()
        y = labels
        
        # Append to the aggregate lists
        X_all.append(X)
        y_all.append(y)
        
        print(f"Loaded {X.shape[0]} epochs from {edf_file}.")
        
    except Exception as e:
        print(f"Failed to process {edf_file}. Error: {e}")


'''
# Define the path to the EDF file
edf_file = '../data/raw data/S001/S001R04.edf'

# Load the raw EEG data
raw = mne.io.read_raw_edf(edf_file, preload=True)

# Display basic information about the loaded data
print(raw.info)

# Plot raw EEG data interactively (optional)
# raw.plot(duration=30, n_channels=30, scalings='auto', title='Raw EEG Signals', show=True)

# Load the raw EEG data with annotations
raw = mne.io.read_raw_edf(edf_file, preload=True)

# Access annotations
annotations = raw.annotations

# Display annotations
print(annotations)

# Define event dictionary
event_dict = {
    'Rest': 1,                # T0
    'Imagining Left Hand': 2,  # T1
    'Imagining Right Hand': 3  # T2
}

# Convert annotations to events and event_id
events, event_id = mne.events_from_annotations(raw)

# Update event_id with descriptive labels
event_id = {
    'Rest': 1,
    'Imagining Left Hand': 2,
    'Imagining Right Hand': 3
}

print(event_id)

from mne import Epochs

# Define epoch parameters
tmin = -0.2  # 200 ms before the event
tmax = 3.8   # 3800 ms after the event
baseline = (None, 0)  # Baseline correction

# Create epochs
epochs = Epochs(raw, events, event_id=event_id, tmin=tmin, tmax=tmax, baseline=baseline, preload=True)

# Display epoch information
print(epochs)

# Plot an average epoch for 'Imagining Left Hand' (optional)
# fig = epochs['Imagining Left Hand'].average().plot()
# fig.suptitle('Imagining Left Hand')
# plt.show()

# Plot an average epoch for 'Imagining Right Hand' (optional)
# fig = epochs['Imagining Right Hand'].average().plot()
# fig.suptitle('Imagining Right Hand')
# plt.show()

# Plot an average epoch for 'Rest' (optional)
# fig = epochs['Rest'].average().plot()
# fig.suptitle('Rest')
# plt.show()

# Select only 'Imagining Left Hand' and 'Imagining Right Hand' epochs
motor_epochs = epochs[['Imagining Left Hand', 'Imagining Right Hand']]

# Extract labels: 0 for Left, 1 for Right
labels = motor_epochs.events[:, -1] - 2  # 'Imagining Left Hand' = 2, 'Imagining Right Hand' = 3

# Verify the distribution of classes
print("Class distribution:", np.bincount(labels))

# Get the data as a NumPy array: shape (n_epochs, n_channels, n_times)
X = motor_epochs.get_data()
y = labels

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
'''
# Out:
# Processing file: S038R12.edf for subject: S038
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S038R12.edf.
#
# Processing file: S038R04.edf for subject: S038
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S038R04.edf.
#
# Processing file: S038R08.edf for subject: S038
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S038R08.edf.
#
# Processing file: S007R08.edf for subject: S007
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S007R08.edf.
#
# Processing file: S007R04.edf for subject: S007
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S007R04.edf.
#
# Processing file: S007R12.edf for subject: S007
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S007R12.edf.
#
# Processing file: S031R08.edf for subject: S031
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S031R08.edf.
#
# Processing file: S031R04.edf for subject: S031
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S031R04.edf.
#
# Processing file: S031R12.edf for subject: S031
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S031R12.edf.
#
# Processing file: S009R08.edf for subject: S009
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S009R08.edf.
#
# Processing file: S009R12.edf for subject: S009
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S009R12.edf.
#
# Processing file: S009R04.edf for subject: S009
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S009R04.edf.
#
# Processing file: S036R04.edf for subject: S036
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S036R04.edf.
#
# Processing file: S036R12.edf for subject: S036
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S036R12.edf.
#
# Processing file: S036R08.edf for subject: S036
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S036R08.edf.
#
# Processing file: S096R04.edf for subject: S096
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S096R04.edf.
#
# Processing file: S096R12.edf for subject: S096
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S096R12.edf.
#
# Processing file: S096R08.edf for subject: S096
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S096R08.edf.
#
# Processing file: S062R08.edf for subject: S062
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S062R08.edf.
#
# Processing file: S062R12.edf for subject: S062
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S062R12.edf.
#
# Processing file: S062R04.edf for subject: S062
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S062R04.edf.
#
# Processing file: S065R12.edf for subject: S065
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S065R12.edf.
#
# Processing file: S065R04.edf for subject: S065
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S065R04.edf.
#
# Processing file: S065R08.edf for subject: S065
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S065R08.edf.
#
# Processing file: S091R08.edf for subject: S091
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S091R08.edf.
#
# Processing file: S091R04.edf for subject: S091
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S091R04.edf.
#
# Processing file: S091R12.edf for subject: S091
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S091R12.edf.
#
# Processing file: S053R12.edf for subject: S053
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S053R12.edf.
#
# Processing file: S053R04.edf for subject: S053
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S053R04.edf.
#
# Processing file: S053R08.edf for subject: S053
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S053R08.edf.
#
# Processing file: S098R12.edf for subject: S098
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S098R12.edf.
#
# Processing file: S098R04.edf for subject: S098
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S098R04.edf.
#
# Processing file: S098R08.edf for subject: S098
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S098R08.edf.
#
# Processing file: S054R08.edf for subject: S054
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S054R08.edf.
#
# Processing file: S054R12.edf for subject: S054
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S054R12.edf.
#
# Processing file: S054R04.edf for subject: S054
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S054R04.edf.
#
# Processing file: S008R04.edf for subject: S008
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S008R04.edf.
#
# Processing file: S008R12.edf for subject: S008
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S008R12.edf.
#
# Processing file: S008R08.edf for subject: S008
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S008R08.edf.
#
# Processing file: S037R08.edf for subject: S037
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S037R08.edf.
#
# Processing file: S037R12.edf for subject: S037
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S037R12.edf.
#
# Processing file: S037R04.edf for subject: S037
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S037R04.edf.
#
# Processing file: S030R12.edf for subject: S030
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S030R12.edf.
#
# Processing file: S030R04.edf for subject: S030
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S030R04.edf.
#
# Processing file: S030R08.edf for subject: S030
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S030R08.edf.
#
# Processing file: S039R08.edf for subject: S039
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S039R08.edf.
#
# Processing file: S039R04.edf for subject: S039
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S039R04.edf.
#
# Processing file: S039R12.edf for subject: S039
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S039R12.edf.
#
# Processing file: S006R12.edf for subject: S006
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S006R12.edf.
#
# Processing file: S006R04.edf for subject: S006
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S006R04.edf.
#
# Processing file: S006R08.edf for subject: S006
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S006R08.edf.
#
# Processing file: S001R08.edf for subject: S001
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S001R08.edf.
#
# Processing file: S001R12.edf for subject: S001
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S001R12.edf.
#
# Processing file: S001R04.edf for subject: S001
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S001R04.edf.
#
# Processing file: S055R04.edf for subject: S055
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S055R04.edf.
#
# Processing file: S055R12.edf for subject: S055
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S055R12.edf.
#
# Processing file: S055R08.edf for subject: S055
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S055R08.edf.
#
# Processing file: S052R08.edf for subject: S052
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S052R08.edf.
#
# Processing file: S052R04.edf for subject: S052
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S052R04.edf.
#
# Processing file: S052R12.edf for subject: S052
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S052R12.edf.
#
# Processing file: S099R08.edf for subject: S099
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S099R08.edf.
#
# Processing file: S099R04.edf for subject: S099
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S099R04.edf.
#
# Processing file: S099R12.edf for subject: S099
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S099R12.edf.
#
# Processing file: S090R12.edf for subject: S090
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S090R12.edf.
#
# Processing file: S090R04.edf for subject: S090
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S090R04.edf.
#
# Processing file: S090R08.edf for subject: S090
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S090R08.edf.
#
# Processing file: S064R08.edf for subject: S064
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S064R08.edf.
#
# Processing file: S064R04.edf for subject: S064
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S064R04.edf.
#
# Processing file: S064R12.edf for subject: S064
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S064R12.edf.
#
# Processing file: S063R04.edf for subject: S063
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S063R04.edf.
#
# Processing file: S063R12.edf for subject: S063
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S063R12.edf.
#
# Processing file: S063R08.edf for subject: S063
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S063R08.edf.
#
# Processing file: S097R08.edf for subject: S097
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S097R08.edf.
#
# Processing file: S097R12.edf for subject: S097
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S097R12.edf.
#
# Processing file: S097R04.edf for subject: S097
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S097R04.edf.
#
# Processing file: S041R12.edf for subject: S041
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S041R12.edf.
#
# Processing file: S041R04.edf for subject: S041
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S041R04.edf.
#
# Processing file: S041R08.edf for subject: S041
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S041R08.edf.
#
# Processing file: S079R04.edf for subject: S079
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S079R04.edf.
#
# Processing file: S079R12.edf for subject: S079
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S079R12.edf.
#
# Processing file: S079R08.edf for subject: S079
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S079R08.edf.
#
# Processing file: S046R08.edf for subject: S046
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S046R08.edf.
#
# Processing file: S046R12.edf for subject: S046
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S046R12.edf.
#
# Processing file: S046R04.edf for subject: S046
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S046R04.edf.
#
# Processing file: S084R04.edf for subject: S084
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S084R04.edf.
#
# Processing file: S084R12.edf for subject: S084
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S084R12.edf.
#
# Processing file: S084R08.edf for subject: S084
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S084R08.edf.
#
# Processing file: S070R08.edf for subject: S070
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S070R08.edf.
#
# Processing file: S070R12.edf for subject: S070
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S070R12.edf.
#
# Processing file: S070R04.edf for subject: S070
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S070R04.edf.
#
# Processing file: S048R08.edf for subject: S048
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S048R08.edf.
#
# Processing file: S048R04.edf for subject: S048
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S048R04.edf.
#
# Processing file: S048R12.edf for subject: S048
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S048R12.edf.
#
# Processing file: S077R12.edf for subject: S077
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S077R12.edf.
#
# Processing file: S077R04.edf for subject: S077
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S077R04.edf.
#
# Processing file: S077R08.edf for subject: S077
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S077R08.edf.
#
# Processing file: S083R08.edf for subject: S083
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S083R08.edf.
#
# Processing file: S083R04.edf for subject: S083
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S083R04.edf.
#
# Processing file: S083R12.edf for subject: S083
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S083R12.edf.
#
# Processing file: S023R08.edf for subject: S023
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S023R08.edf.
#
# Processing file: S023R04.edf for subject: S023
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S023R04.edf.
#
# Processing file: S023R12.edf for subject: S023
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S023R12.edf.
#
# Processing file: S024R04.edf for subject: S024
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S024R04.edf.
#
# Processing file: S024R12.edf for subject: S024
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S024R12.edf.
#
# Processing file: S024R08.edf for subject: S024
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S024R08.edf.
#
# Processing file: S012R04.edf for subject: S012
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S012R04.edf.
#
# Processing file: S012R12.edf for subject: S012
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S012R12.edf.
#
# Processing file: S012R08.edf for subject: S012
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S012R08.edf.
#
# Processing file: S015R08.edf for subject: S015
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S015R08.edf.
#
# Processing file: S015R04.edf for subject: S015
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S015R04.edf.
#
# Processing file: S015R12.edf for subject: S015
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S015R12.edf.
#
# Processing file: S049R12.edf for subject: S049
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S049R12.edf.
#
# Processing file: S049R04.edf for subject: S049
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S049R04.edf.
#
# Processing file: S049R08.edf for subject: S049
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S049R08.edf.
#
# Processing file: S082R12.edf for subject: S082
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S082R12.edf.
#
# Processing file: S082R04.edf for subject: S082
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S082R04.edf.
#
# Processing file: S082R08.edf for subject: S082
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S082R08.edf.
#
# Processing file: S076R08.edf for subject: S076
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S076R08.edf.
#
# Processing file: S076R04.edf for subject: S076
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S076R04.edf.
#
# Processing file: S076R12.edf for subject: S076
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S076R12.edf.
#
# Processing file: S071R04.edf for subject: S071
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S071R04.edf.
#
# Processing file: S071R12.edf for subject: S071
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S071R12.edf.
#
# Processing file: S071R08.edf for subject: S071
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S071R08.edf.
#
# Processing file: S085R08.edf for subject: S085
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S085R08.edf.
#
# Processing file: S085R12.edf for subject: S085
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S085R12.edf.
#
# Processing file: S085R04.edf for subject: S085
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S085R04.edf.
#
# Processing file: S078R08.edf for subject: S078
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S078R08.edf.
#
# Processing file: S078R12.edf for subject: S078
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S078R12.edf.
#
# Processing file: S078R04.edf for subject: S078
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S078R04.edf.
#
# Processing file: S047R04.edf for subject: S047
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S047R04.edf.
#
# Processing file: S047R12.edf for subject: S047
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S047R12.edf.
#
# Processing file: S047R08.edf for subject: S047
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S047R08.edf.
#
# Processing file: S040R08.edf for subject: S040
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S040R08.edf.
#
# Processing file: S040R04.edf for subject: S040
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S040R04.edf.
#
# Processing file: S040R12.edf for subject: S040
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S040R12.edf.
#
# Processing file: S014R12.edf for subject: S014
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S014R12.edf.
#
# Processing file: S014R04.edf for subject: S014
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S014R04.edf.
#
# Processing file: S014R08.edf for subject: S014
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S014R08.edf.
#
# Processing file: S013R08.edf for subject: S013
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S013R08.edf.
#
# Processing file: S013R12.edf for subject: S013
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S013R12.edf.
#
# Processing file: S013R04.edf for subject: S013
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S013R04.edf.
#
# Processing file: S025R08.edf for subject: S025
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S025R08.edf.
#
# Processing file: S025R12.edf for subject: S025
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S025R12.edf.
#
# Processing file: S025R04.edf for subject: S025
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S025R04.edf.
#
# Processing file: S022R12.edf for subject: S022
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S022R12.edf.
#
# Processing file: S022R04.edf for subject: S022
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S022R04.edf.
#
# Processing file: S022R08.edf for subject: S022
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S022R08.edf.
#
# Processing file: S103R08.edf for subject: S103
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S103R08.edf.
#
# Processing file: S103R04.edf for subject: S103
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S103R04.edf.
#
# Processing file: S103R12.edf for subject: S103
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S103R12.edf.
#
# Processing file: S104R04.edf for subject: S104
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S104R04.edf.
#
# Processing file: S104R12.edf for subject: S104
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S104R12.edf.
#
# Processing file: S104R08.edf for subject: S104
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 12 epochs from S104R08.edf.
#
# Processing file: S105R08.edf for subject: S105
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S105R08.edf.
#
# Processing file: S105R12.edf for subject: S105
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S105R12.edf.
#
# Processing file: S105R04.edf for subject: S105
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S105R04.edf.
#
# Processing file: S102R12.edf for subject: S102
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S102R12.edf.
#
# Processing file: S102R04.edf for subject: S102
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S102R04.edf.
#
# Processing file: S102R08.edf for subject: S102
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S102R08.edf.
#
# Processing file: S066R08.edf for subject: S066
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S066R08.edf.
#
# Processing file: S066R12.edf for subject: S066
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S066R12.edf.
#
# Processing file: S066R04.edf for subject: S066
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S066R04.edf.
#
# Processing file: S092R04.edf for subject: S092
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 19 epochs from S092R04.edf.
#
# Processing file: S092R12.edf for subject: S092
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 19 epochs from S092R12.edf.
#
# Processing file: S092R08.edf for subject: S092
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 19 epochs from S092R08.edf.
#
# Processing file: S059R04.edf for subject: S059
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S059R04.edf.
#
# Processing file: S059R12.edf for subject: S059
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S059R12.edf.
#
# Processing file: S059R08.edf for subject: S059
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S059R08.edf.
#
# Processing file: S095R08.edf for subject: S095
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S095R08.edf.
#
# Processing file: S095R04.edf for subject: S095
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S095R04.edf.
#
# Processing file: S095R12.edf for subject: S095
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S095R12.edf.
#
# Processing file: S061R12.edf for subject: S061
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S061R12.edf.
#
# Processing file: S061R04.edf for subject: S061
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S061R04.edf.
#
# Processing file: S061R08.edf for subject: S061
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S061R08.edf.
#
# Processing file: S057R12.edf for subject: S057
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S057R12.edf.
#
# Processing file: S057R04.edf for subject: S057
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S057R04.edf.
#
# Processing file: S057R08.edf for subject: S057
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S057R08.edf.
#
# Processing file: S068R08.edf for subject: S068
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S068R08.edf.
#
# Processing file: S068R04.edf for subject: S068
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S068R04.edf.
#
# Processing file: S068R12.edf for subject: S068
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S068R12.edf.
#
# Processing file: S050R08.edf for subject: S050
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S050R08.edf.
#
# Processing file: S050R12.edf for subject: S050
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S050R12.edf.
#
# Processing file: S050R04.edf for subject: S050
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S050R04.edf.
#
# Processing file: S004R04.edf for subject: S004
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S004R04.edf.
#
# Processing file: S004R12.edf for subject: S004
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S004R12.edf.
#
# Processing file: S004R08.edf for subject: S004
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S004R08.edf.
#
# Processing file: S003R08.edf for subject: S003
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S003R08.edf.
#
# Processing file: S003R04.edf for subject: S003
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S003R04.edf.
#
# Processing file: S003R12.edf for subject: S003
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S003R12.edf.
#
# Processing file: S035R08.edf for subject: S035
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S035R08.edf.
#
# Processing file: S035R04.edf for subject: S035
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S035R04.edf.
#
# Processing file: S035R12.edf for subject: S035
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S035R12.edf.
#
# Processing file: S032R04.edf for subject: S032
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S032R04.edf.
#
# Processing file: S032R12.edf for subject: S032
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S032R12.edf.
#
# Processing file: S032R08.edf for subject: S032
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S032R08.edf.
#
# Processing file: S051R04.edf for subject: S051
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S051R04.edf.
#
# Processing file: S051R12.edf for subject: S051
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S051R12.edf.
#
# Processing file: S051R08.edf for subject: S051
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S051R08.edf.
#
# Processing file: S056R08.edf for subject: S056
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S056R08.edf.
#
# Processing file: S056R04.edf for subject: S056
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S056R04.edf.
#
# Processing file: S056R12.edf for subject: S056
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S056R12.edf.
#
# Processing file: S069R12.edf for subject: S069
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S069R12.edf.
#
# Processing file: S069R04.edf for subject: S069
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# ...
# Loaded 15 epochs from S010R08.edf.
#
# Processing file: S017R08.edf for subject: S017
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S017R08.edf.
#
# Processing file: S017R12.edf for subject: S017
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S017R12.edf.
#
# Processing file: S017R04.edf for subject: S017
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S017R04.edf.
#
# Processing file: S028R04.edf for subject: S028
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S028R04.edf.
#
# Processing file: S028R12.edf for subject: S028
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S028R12.edf.
#
# Processing file: S028R08.edf for subject: S028
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S028R08.edf.
#
# Processing file: S021R08.edf for subject: S021
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S021R08.edf.
#
# Processing file: S021R12.edf for subject: S021
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S021R12.edf.
#
# Processing file: S021R04.edf for subject: S021
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S021R04.edf.
#
# Processing file: S026R12.edf for subject: S026
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S026R12.edf.
#
# Processing file: S026R04.edf for subject: S026
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S026R04.edf.
#
# Processing file: S026R08.edf for subject: S026
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S026R08.edf.
#
# Processing file: S019R08.edf for subject: S019
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S019R08.edf.
#
# Processing file: S019R04.edf for subject: S019
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S019R04.edf.
#
# Processing file: S019R12.edf for subject: S019
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S019R12.edf.
#
# Processing file: S072R08.edf for subject: S072
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S072R08.edf.
#
# Processing file: S072R04.edf for subject: S072
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S072R04.edf.
#
# Processing file: S072R12.edf for subject: S072
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S072R12.edf.
#
# Processing file: S086R12.edf for subject: S086
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S086R12.edf.
#
# Processing file: S086R04.edf for subject: S086
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S086R04.edf.
#
# Processing file: S086R08.edf for subject: S086
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S086R08.edf.
#
# Processing file: S081R08.edf for subject: S081
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S081R08.edf.
#
# Processing file: S081R12.edf for subject: S081
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S081R12.edf.
#
# Processing file: S081R04.edf for subject: S081
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S081R04.edf.
#
# Processing file: S075R04.edf for subject: S075
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S075R04.edf.
#
# Processing file: S075R12.edf for subject: S075
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S075R12.edf.
#
# Processing file: S075R08.edf for subject: S075
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S075R08.edf.
#
# Processing file: S088R04.edf for subject: S088
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 19 epochs from S088R04.edf.
#
# Processing file: S088R12.edf for subject: S088
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 19 epochs from S088R12.edf.
#
# Processing file: S088R08.edf for subject: S088
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 19 epochs from S088R08.edf.
#
# Processing file: S043R04.edf for subject: S043
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S043R04.edf.
#
# Processing file: S043R12.edf for subject: S043
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S043R12.edf.
#
# Processing file: S043R08.edf for subject: S043
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S043R08.edf.
#
# Processing file: S044R08.edf for subject: S044
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S044R08.edf.
#
# Processing file: S044R04.edf for subject: S044
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S044R04.edf.
#
# Processing file: S044R12.edf for subject: S044
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S044R12.edf.
#
# Processing file: S109R08.edf for subject: S109
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S109R08.edf.
#
# Processing file: S109R12.edf for subject: S109
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S109R12.edf.
#
# Processing file: S109R04.edf for subject: S109
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S109R04.edf.
#
# Processing file: S107R08.edf for subject: S107
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S107R08.edf.
#
# Processing file: S107R04.edf for subject: S107
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S107R04.edf.
#
# Processing file: S107R12.edf for subject: S107
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S107R12.edf.
#
# Processing file: S100R04.edf for subject: S100
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 12 epochs from S100R04.edf.
#
# Processing file: S100R12.edf for subject: S100
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 12 epochs from S100R12.edf.
#
# Processing file: S100R08.edf for subject: S100
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 12 epochs from S100R08.edf.
#
# Processing file: S101R08.edf for subject: S101
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S101R08.edf.
#
# Processing file: S101R12.edf for subject: S101
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S101R12.edf.
#
# Processing file: S101R04.edf for subject: S101
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S101R04.edf.
#
# Processing file: S106R12.edf for subject: S106
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S106R12.edf.
#
# Processing file: S106R04.edf for subject: S106
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# /var/folders/64/t0s5x1395f38bgfnfwy0_cdh0000gn/T/ipykernel_19654/1908462150.py:30: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /var/folders/64/t0s5x1395f38bgfnfwy0_cdh0000gn/T/ipykernel_19654/1908462150.py:30: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /var/folders/64/t0s5x1395f38bgfnfwy0_cdh0000gn/T/ipykernel_19654/1908462150.py:30: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# Loaded 15 epochs from S106R04.edf.
#
# Processing file: S106R08.edf for subject: S106
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S106R08.edf.
#
# Processing file: S108R04.edf for subject: S108
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S108R04.edf.
#
# Processing file: S108R12.edf for subject: S108
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S108R12.edf.
#
# Processing file: S108R08.edf for subject: S108
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Loaded 15 epochs from S108R08.edf.
# '\n# Define the path to the EDF file\nedf_file = \'../data/raw data/S001/S001R04.edf\'\n\n# Load the raw EEG data\nraw = mne.io.read_raw_edf(edf_file, preload=True)\n\n# Display basic information about the loaded data\nprint(raw.info)\n\n# Plot raw EEG data interactively (optional)\n# raw.plot(duration=30, n_channels=30, scalings=\'auto\', title=\'Raw EEG Signals\', show=True)\n\n# Load the raw EEG data with annotations\nraw = mne.io.read_raw_edf(edf_file, preload=True)\n\n# Access annotations\nannotations = raw.annotations\n\n# Display annotations\nprint(annotations)\n\n# Define event dictionary\nevent_dict = {\n    \'Rest\': 1,                # T0\n    \'Imagining Left Hand\': 2,  # T1\n    \'Imagining Right Hand\': 3  # T2\n}\n\n# Convert annotations to events and event_id\nevents, event_id = mne.events_from_annotations(raw)\n\n# Update event_id with descriptive labels\nevent_id = {\n    \'Rest\': 1,\n    \'Imagining Left Hand\': 2,\n    \'Imagining Right Hand\': 3\n}\n\nprint(event_id)\n\nfrom mne import Epochs\n\n# Define epoch parameters\ntmin = -0.2  # 200 ms before the event\ntmax = 3.8   # 3800 ms after the event\nbaseline = (None, 0)  # Baseline correction\n\n# Create epochs\nepochs = Epochs(raw, events, event_id=event_id, tmin=tmin, tmax=tmax, baseline=baseline, preload=True)\n\n# Display epoch information\nprint(epochs)\n\n# Plot an average epoch for \'Imagining Left Hand\' (optional)\n# fig = epochs[\'Imagining Left Hand\'].average().plot()\n# fig.suptitle(\'Imagining Left Hand\')\n# plt.show()\n\n# Plot an average epoch for \'Imagining Right Hand\' (optional)\n# fig = epochs[\'Imagining Right Hand\'].average().plot()\n# fig.suptitle(\'Imagining Right Hand\')\n# plt.show()\n\n# Plot an average epoch for \'Rest\' (optional)\n# fig = epochs[\'Rest\'].average().plot()\n# fig.suptitle(\'Rest\')\n# plt.show()\n\n# Select only \'Imagining Left Hand\' and \'Imagining Right Hand\' epochs\nmotor_epochs = epochs[[\'Imagining Left Hand\', \'Imagining Right Hand\']]\n\n# Extract labels: 0 for Left, 1 for Right\nlabels = motor_epochs.events[:, -1] - 2  # \'Imagining Left Hand\' = 2, \'Imagining Right Hand\' = 3\n\n# Verify the distribution of classes\nprint("Class distribution:", np.bincount(labels))\n\n# Get the data as a NumPy array: shape (n_epochs, n_channels, n_times)\nX = motor_epochs.get_data()\ny = labels\n\nprint(f"Shape of X: {X.shape}")\nprint(f"Shape of y: {y.shape}")\n'

# %%
print(f"Total number of files processed: {len(X_all)}")
print(f"Total number of labels collected: {len(y_all)}")
# Out:
# Total number of files processed: 327
# Total number of labels collected: 327

# %%
all_epochs = []
all_labels = []

for idx, row in df_files.iterrows():
    # ... load and process each file to get X and y ...
    # Suppose after processing a file, you have:
    # X (n_epochs, n_channels, n_times)
    # y (n_epochs,)

    all_epochs.append(X)
    all_labels.append(y)

X_all = np.concatenate(all_epochs, axis=0)
y_all = np.concatenate(all_labels, axis=0)

print("X_all shape:", X_all.shape)
print("y_all shape:", y_all.shape)
# Out:
# X_all shape: (4905, 64, 641)
# y_all shape: (4905,)

# %%
import numpy as np
import logging
from sklearn.base import BaseEstimator, TransformerMixin
from mne.filter import filter_data
from mne.decoding import CSP

# Configure logging: 
# Set level=logging.INFO for less verbosity, level=logging.DEBUG for more details
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class FBCSP(BaseEstimator, TransformerMixin):
    def __init__(self, freq_bands, n_csp=4, sfreq=160, filter_method='iir', csp_reg=None):
        """
        Filter Bank Common Spatial Pattern (FBCSP) transformer.

        Parameters
        ----------
        freq_bands : list of tuple
            List of frequency bands (l_freq, h_freq).
        n_csp : int, optional
            Number of CSP components per band, by default 4.
        sfreq : float, optional
            Sampling frequency of the EEG data, by default 160.
        filter_method : str, optional
            Filtering method to use ('iir' or 'fir'), by default 'iir'.
        csp_reg : None or str or float, optional
            Regularization parameter for CSP. 
            Examples: None, 'ledoit_wolf', 'oas', or float values. See MNE CSP docs.
        """
        self.freq_bands = freq_bands
        self.n_csp = n_csp
        self.sfreq = sfreq
        self.filter_method = filter_method
        self.csp_reg = csp_reg
        self.csp_list_ = []

    def fit(self, X, y):
        """
        Fit CSP models for each frequency band.

        Parameters
        ----------
        X : np.ndarray, shape (n_trials, n_channels, n_times)
            EEG data.
        y : np.ndarray, shape (n_trials,)
            Class labels.

        Returns
        -------
        self : object
            Fitted FBCSP instance.
        """
        # Validate input shapes
        if X.ndim != 3:
            raise ValueError(f"X should be 3D (n_trials, n_channels, n_times). Got shape: {X.shape}")
        if X.shape[0] != len(y):
            raise ValueError("Number of trials in X does not match length of y.")

        self.csp_list_ = []
        for band in self.freq_bands:
            l_freq, h_freq = band
            logging.info(f"Fitting CSP for band: {l_freq}-{h_freq} Hz")

            # Band-pass filter the data for the current frequency band
            X_filtered = np.array([
                filter_data(trial, sfreq=self.sfreq, l_freq=l_freq, h_freq=h_freq, 
                            method=self.filter_method, verbose=False)
                for trial in X
            ])

            # Initialize and fit CSP for the current band
            csp = CSP(n_components=self.n_csp, reg=self.csp_reg, log=True, norm_trace=False)
            csp.fit(X_filtered, y)
            self.csp_list_.append(csp)

        return self

    def transform(self, X):
        """
        Transform EEG data using the fitted CSP models.

        Parameters
        ----------
        X : np.ndarray, shape (n_trials, n_channels, n_times)
            EEG data to transform.

        Returns
        -------
        X_features : np.ndarray, shape (n_trials, n_bands * n_csp)
            Extracted features.
        """
        # Validate input shapes
        if X.ndim != 3:
            raise ValueError(f"X should be 3D (n_trials, n_channels, n_times). Got shape: {X.shape}")

        # Ensure that the CSPs have been fitted
        if not self.csp_list_:
            raise RuntimeError("FBCSP has not been fitted yet. Call fit before transform.")

        features = []
        for idx, (l_freq, h_freq) in enumerate(self.freq_bands):
            logging.info(f"Transforming data for band: {l_freq}-{h_freq} Hz")
            csp = self.csp_list_[idx]

            # Band-pass filter the data for the current frequency band
            X_filtered = np.array([
                filter_data(trial, sfreq=self.sfreq, l_freq=l_freq, h_freq=h_freq, 
                            method=self.filter_method, verbose=False)
                for trial in X
            ])

            # Apply CSP transformation
            X_csp = csp.transform(X_filtered)

            # Extract log-variance features
            # shape: (n_trials,) -> reshape to (n_trials, 1)
            X_logvar = np.log(np.var(X_csp, axis=1)).reshape(-1, 1)

            features.append(X_logvar)

        # Concatenate features from all bands
        X_features = np.column_stack(features)
        return X_features

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline

#frequency bands (already defined previously)
freq_bands = [
    (8, 12),    # Alpha
    (13, 20),   # Beta 1
    (21, 30),   # Beta 2
    (31, 40),   # Low Gamma
    (41, 50),   # High Gamma
    (51, 60),   # Very High Gamma
    (61, 70),   # Ultra High Gamma
    (71, 79)    # Max Gamma
]

# Instantiate the FBCSP transformer with desired parameters
fbcsp = FBCSP(freq_bands=freq_bands, n_csp=4, sfreq=160, filter_method='iir', csp_reg=None)

# Instantiate the Random Forest classifier with 10 trees
rf = RandomForestClassifier(n_estimators=10, random_state=42)

# Build the pipeline: first apply FBCSP, then classify with Random Forest
pipeline = Pipeline([
    ('fbcsp', fbcsp),
    ('classifier', rf)
])

# Define cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Perform cross-validation
scores = cross_val_score(pipeline, X_all, y_all, cv=cv, scoring='accuracy')

print("Cross-validation accuracy scores:", scores)
print(f"Mean accuracy: {scores.mean() * 100:.2f}%")
print(f"Standard deviation: {scores.std() * 100:.2f}%")

# Fit the pipeline on all data
pipeline.fit(X_all, y_all)
# Out:
# 2024-12-09 11:12:19,700 - INFO - Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0017 (2.2e-16 eps * 64 dim * 1.2e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:13:10,872 - INFO - Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 8.9e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:13:58,232 - INFO - Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 9.5e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:14:47,810 - INFO - Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0011 (2.2e-16 eps * 64 dim * 7.5e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:15:35,027 - INFO - Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00087 (2.2e-16 eps * 64 dim * 6.1e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:16:20,570 - INFO - Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00078 (2.2e-16 eps * 64 dim * 5.5e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:17:07,360 - INFO - Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00066 (2.2e-16 eps * 64 dim * 4.7e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:17:54,690 - INFO - Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00054 (2.2e-16 eps * 64 dim * 3.8e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:18:47,705 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 11:19:25,941 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 11:20:01,766 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 11:20:38,186 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 11:21:14,670 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 11:21:51,736 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 11:22:27,666 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 11:23:03,184 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 11:23:43,819 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 11:23:53,375 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 11:24:02,287 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 11:24:10,916 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 11:24:19,430 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 11:24:27,876 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 11:24:36,539 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 11:24:45,339 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 11:24:56,110 - INFO - Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0017 (2.2e-16 eps * 64 dim * 1.2e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:25:46,310 - INFO - Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 8.9e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:26:33,934 - INFO - Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 9.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:27:19,101 - INFO - Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0011 (2.2e-16 eps * 64 dim * 7.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:28:07,261 - INFO - Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00086 (2.2e-16 eps * 64 dim * 6.1e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:28:55,151 - INFO - Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00077 (2.2e-16 eps * 64 dim * 5.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:29:44,823 - INFO - Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00066 (2.2e-16 eps * 64 dim * 4.6e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:30:32,458 - INFO - Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00054 (2.2e-16 eps * 64 dim * 3.8e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:31:24,121 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 11:32:04,084 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 11:32:42,100 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 11:33:19,697 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 11:33:56,517 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 11:34:32,208 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 11:35:10,148 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 11:35:48,373 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 11:36:29,985 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 11:36:39,710 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 11:36:49,004 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 11:36:58,368 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 11:37:07,778 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 11:37:17,266 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 11:37:26,553 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 11:37:36,073 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 11:37:47,318 - INFO - Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0017 (2.2e-16 eps * 64 dim * 1.2e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:38:38,256 - INFO - Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 8.9e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:39:23,550 - INFO - Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 9.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:40:08,359 - INFO - Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0011 (2.2e-16 eps * 64 dim * 7.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:40:52,956 - INFO - Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00087 (2.2e-16 eps * 64 dim * 6.1e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:41:38,395 - INFO - Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00077 (2.2e-16 eps * 64 dim * 5.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:42:23,584 - INFO - Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00066 (2.2e-16 eps * 64 dim * 4.7e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:43:08,741 - INFO - Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00054 (2.2e-16 eps * 64 dim * 3.8e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:43:56,760 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 11:44:32,767 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 11:45:09,977 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 11:45:47,587 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 11:46:24,584 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 11:47:02,319 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 11:47:40,891 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 11:48:19,403 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 11:49:00,961 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 11:49:10,638 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 11:49:19,989 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 11:49:29,097 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 11:49:38,158 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 11:49:46,738 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 11:49:55,328 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 11:50:03,902 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 11:50:13,806 - INFO - Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0017 (2.2e-16 eps * 64 dim * 1.2e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:51:00,626 - INFO - Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 8.9e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:51:46,140 - INFO - Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 9.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:52:33,266 - INFO - Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0011 (2.2e-16 eps * 64 dim * 7.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:53:21,141 - INFO - Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00087 (2.2e-16 eps * 64 dim * 6.1e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:54:09,020 - INFO - Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00078 (2.2e-16 eps * 64 dim * 5.5e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:54:56,071 - INFO - Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00066 (2.2e-16 eps * 64 dim * 4.7e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:55:43,010 - INFO - Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00054 (2.2e-16 eps * 64 dim * 3.8e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 11:56:32,559 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 11:57:11,417 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 11:57:49,380 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 11:58:27,380 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 11:59:05,426 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 11:59:43,445 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 12:00:21,727 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 12:01:00,512 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 12:01:42,478 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 12:01:52,480 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 12:02:02,008 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 12:02:11,475 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 12:02:20,934 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 12:02:30,213 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 12:02:38,987 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 12:02:47,575 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 12:02:57,459 - INFO - Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0017 (2.2e-16 eps * 64 dim * 1.2e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:03:44,047 - INFO - Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 8.9e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:04:29,398 - INFO - Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 9.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:05:14,402 - INFO - Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0011 (2.2e-16 eps * 64 dim * 7.4e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:06:00,691 - INFO - Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00087 (2.2e-16 eps * 64 dim * 6.1e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:06:48,848 - INFO - Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00078 (2.2e-16 eps * 64 dim * 5.5e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:07:34,655 - INFO - Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00066 (2.2e-16 eps * 64 dim * 4.7e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:08:22,146 - INFO - Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00054 (2.2e-16 eps * 64 dim * 3.8e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:09:15,814 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 12:09:53,554 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 12:10:30,753 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 12:11:08,331 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 12:11:45,189 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 12:12:21,619 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 12:12:58,096 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 12:13:34,178 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 12:14:14,500 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 12:14:23,907 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 12:14:32,735 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 12:14:41,335 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 12:14:50,367 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 12:14:59,017 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 12:15:07,553 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 12:15:16,164 - INFO - Transforming data for band: 71-79 Hz
# 2024-12-09 12:15:25,596 - INFO - Fitting CSP for band: 8-12 Hz
# Cross-validation accuracy scores: [1. 1. 1. 1. 1.]
# Mean accuracy: 100.00%
# Standard deviation: 0.00%
# Computing rank from data with rank=None
#     Using tolerance 0.0019 (2.2e-16 eps * 64 dim * 1.3e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:16:23,697 - INFO - Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0014 (2.2e-16 eps * 64 dim * 9.9e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:17:20,058 - INFO - Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0015 (2.2e-16 eps * 64 dim * 1.1e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:18:17,289 - INFO - Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.0012 (2.2e-16 eps * 64 dim * 8.3e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:19:13,984 - INFO - Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00097 (2.2e-16 eps * 64 dim * 6.8e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:20:14,392 - INFO - Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00087 (2.2e-16 eps * 64 dim * 6.1e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:21:11,584 - INFO - Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00074 (2.2e-16 eps * 64 dim * 5.2e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:22:07,848 - INFO - Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 0.00061 (2.2e-16 eps * 64 dim * 4.3e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# 2024-12-09 12:23:10,292 - INFO - Transforming data for band: 8-12 Hz
# 2024-12-09 12:23:56,566 - INFO - Transforming data for band: 13-20 Hz
# 2024-12-09 12:24:40,436 - INFO - Transforming data for band: 21-30 Hz
# 2024-12-09 12:25:27,017 - INFO - Transforming data for band: 31-40 Hz
# 2024-12-09 12:26:14,042 - INFO - Transforming data for band: 41-50 Hz
# 2024-12-09 12:27:01,528 - INFO - Transforming data for band: 51-60 Hz
# 2024-12-09 12:27:44,624 - INFO - Transforming data for band: 61-70 Hz
# 2024-12-09 12:28:29,435 - INFO - Transforming data for band: 71-79 Hz
# Pipeline(steps=[('fbcsp',
#                  FBCSP(freq_bands=[(8, 12), (13, 20), (21, 30), (31, 40),
#                                    (41, 50), (51, 60), (61, 70), (71, 79)])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=10, random_state=42))])

# %%
# Check out the rf classifier's accuracy
y_pred = pipeline.predict(X_all)
accuracy = np.mean(y_pred == y_all)
print(f"Accuracy on the entire dataset: {accuracy * 100:.2f}%")
# Out:
# 2024-12-09 12:38:19,194 - INFO - Transforming data for band: 8-12 Hz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Check out the rf classifier's accuracy
# ----> 2 y_pred = pipeline.predict(X_all)
#       3 accuracy = np.mean(y_pred == y_all)
#       4 print(f"Accuracy on the entire dataset: {accuracy * 100:.2f}%")
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/sklearn/pipeline.py:600, in Pipeline.predict(self, X, **params)
#     598 if not _routing_enabled():
#     599     for _, name, transform in self._iter(with_final=False):
# --> 600         Xt = transform.transform(Xt)
#     601     return self.steps[-1][1].predict(Xt, **params)
#     603 # metadata routing enabled
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# Cell In[17], line 107, in FBCSP.transform(self, X)
#     103 csp = self.csp_list_[idx]
#     105 # Band-pass filter the data for the current frequency band
#     106 X_filtered = np.array([
# --> 107     filter_data(trial, sfreq=self.sfreq, l_freq=l_freq, h_freq=h_freq,
#     108                 method=self.filter_method, verbose=False)
#     109     for trial in X
#     110 ])
#     112 # Apply CSP transformation
#     113 X_csp = csp.transform(X_filtered)
#
# File <decorator-gen-81>:10, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/mne/filter.py:1029, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#    1027     data = _overlap_add_filter(data, filt, None, phase, picks, n_jobs, copy, pad)
#    1028 else:
# -> 1029     data = _iir_filter(data, filt, picks, n_jobs, copy, phase)
#    1030 return data
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/mne/filter.py:571, in _iir_filter(x, iir_params, picks, n_jobs, copy, phase)
#     569 if n_jobs == 1:
#     570     for p in picks:
# --> 571         x[p] = fun(x=x[p])
#     572 else:
#     573     data_new = parallel(p_fun(x=x[p]) for p in picks)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/scipy/signal/_signaltools.py:4483, in sosfiltfilt(sos, x, axis, padtype, padlen)
#    4479 edge, ext = _validate_pad(padtype, padlen, x, axis,
#    4480                           ntaps=ntaps)
#    4482 # These steps follow the same form as filtfilt with modifications
# -> 4483 zi = sosfilt_zi(sos)  # shape (n_sections, 2) --> (n_sections, ..., 2, ...)
#    4484 zi_shape = [1] * x.ndim
#    4485 zi_shape[axis] = 2
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/scipy/signal/_signaltools.py:3840, in sosfilt_zi(sos)
#    3838 b = sos[section, :3]
#    3839 a = sos[section, 3:]
# -> 3840 zi[section] = scale * lfilter_zi(b, a)
#    3841 # If H(z) = B(z)/A(z) is this section's transfer function, then
#    3842 # b.sum()/a.sum() is H(1), the gain at omega=0.  That's the steady
#    3843 # state value of this section's step response.
#    3844 scale *= b.sum() / a.sum()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/scipy/signal/_signaltools.py:3756, in lfilter_zi(b, a)
#    3754 B = b[1:] - a[1:] * b[0]
#    3755 # Solve zi = A*zi + B
# -> 3756 zi = np.linalg.solve(IminusA, B)
#    3758 # For future reference: we could also use the following
#    3759 # explicit formulas to solve the linear system:
#    3760 #
#    (...)
#    3767 #     csum += b[k] - a[k]*b[0]
#    3768 #     zi[k] = asum*zi[0] - csum
#    3770 return zi
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/numpy/linalg/_linalg.py:314, in _solve_dispatcher(a, b)
#     310     res.shape = oldshape
#     311     return res
# --> 314 def _solve_dispatcher(a, b):
#     315     return (a, b)
#     318 @array_function_dispatch(_solve_dispatcher)
#     319 def solve(a, b):
#
# KeyboardInterrupt:

# %%
class FBCSP(BaseEstimator, TransformerMixin):
    def __init__(self, freq_bands, n_csp=4, sfreq=160):
        """
        Initialize the FBCSP transformer.
        
        Parameters:
        - freq_bands: List of tuples defining frequency bands.
        - n_csp: Number of CSP components per band.
        - sfreq: Sampling frequency of the EEG data.
        """
        self.freq_bands = freq_bands
        self.n_csp = n_csp
        self.sfreq = sfreq
        self.csp_list_ = []  # To store CSP models for each band

    def fit(self, X, y):
        """
        Fit CSP models for each frequency band.
        
        Parameters:
        - X: EEG data, shape (n_trials, n_channels, n_times)
        - y: Labels, shape (n_trials,)
        
        Returns:
        - self
        """
        self.csp_list_ = []  # Reset in case of multiple fits
        for band in self.freq_bands:
            print(f'Fitting CSP for band: {band[0]}-{band[1]} Hz')
            # Band-pass filter the data for the current frequency band
            X_filtered = np.array([
                filter_data(trial, sfreq=self.sfreq, l_freq=band[0], h_freq=band[1], method='iir', verbose=False)
                for trial in X
            ])
            
            # Initialize and fit CSP
            csp = CSP(n_components=self.n_csp, reg=None, log=True, norm_trace=False)
            csp.fit(X_filtered, y)
            self.csp_list_.append(csp)
        return self

    def transform(self, X):
        """
        Transform EEG data using the fitted CSP models.
        
        Parameters:
        - X: EEG data, shape (n_trials, n_channels, n_times)
        
        Returns:
        - X_features: Extracted features, shape (n_trials, n_bands * n_csp)
        """
        features = []
        for idx, band in enumerate(self.freq_bands):
            print(f'Transforming data for band: {band[0]}-{band[1]} Hz')
            csp = self.csp_list_[idx]
            # Band-pass filter the data for the current frequency band
            X_filtered = np.array([
                filter_data(trial, sfreq=self.sfreq, l_freq=band[0], h_freq=band[1], method='iir', verbose=False)
                for trial in X
            ])
            
            # Apply CSP transformation
            X_csp = csp.transform(X_filtered)
            
            # Extract log-variance features
            X_logvar = np.log(np.var(X_csp, axis=1))
            
            # Reshape X_logvar to (n_trials, 1) to make it 2D
            X_logvar = X_logvar.reshape(-1, 1)
            
            # Append the reshaped feature
            features.append(X_logvar)
        
        # Concatenate features from all bands along axis=1
       
        X_features = np.column_stack(features)
        return X_features

# %%
# Initialize FBCSP transformer
fbcsp = FBCSP(freq_bands=freq_bands, n_csp=4, sfreq=160)  # Replace sfreq with your actual sampling frequency

# Initialize Neural Network classifier
mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)

# Define the classification pipeline
pipeline = Pipeline([
    ('fbcsp', fbcsp),
    ('classifier', mlp)
])

# %%
# Define cross-validation strategy
n_splits = 5  # Adjust based on your dataset size
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Perform cross-validation
print("Starting Cross-Validation...")
scores = cross_val_score(pipeline, X, y, cv=cv, scoring='accuracy')

print(f"\nCross-Validation Accuracy Scores: {scores}")
print(f"Mean Accuracy: {scores.mean() * 100:.2f}%")
print(f"Standard Deviation: {scores.std() * 100:.2f}%")
