# %%
import numpy as np
import mne
from mne.decoding import CSP
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier  # Neural Network Classifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, cross_val_predict, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from mne.filter import filter_data
import matplotlib.pyplot as plt
# Import the required Python libraries
import os
import re
from pathlib import Path
import pandas as pd
import numpy as np
import mne

# %%
# Define the path to your raw_data directory
data_dir = Path('../data/raw data')  # Adjust this path as needed

# Verify the directory exists
if not data_dir.exists():
    raise FileNotFoundError(f"The specified data directory does not exist: {data_dir}")

# Define the specific runs to process, including both two-digit and three-digit run numbers
desired_runs = ['04', '08', '12']

# Compile a regular expression pattern to match filenames like S001R04.edf, S002R08.edf, S001R012.edf, etc.
# This pattern ensures that only R04, R08, R12 are matched
edf_pattern = re.compile(r'^S\d{3}R0?(04|08|12)\.edf$', re.IGNORECASE)

# %%
# Initialize a list to store file information
file_info = []

# Counter for processed subject directories
processed_subjects = 0

# Iterate through each subject folder in raw_data
for subject_dir in data_dir.iterdir():
    if subject_dir.is_dir() and re.match(r'^S\d{3}$', subject_dir.name, re.IGNORECASE):
        processed_subjects += 1
        # Iterate through each file in the subject directory
        for file in subject_dir.iterdir():
            if file.is_file() and edf_pattern.match(file.name):
                # Derive the corresponding event file name
                base_name = file.stem  # e.g., S001R04
                event_file = f"{base_name}.edf.event"
                event_path = subject_dir / event_file
                
                # Check if the event file exists
                event_exists = event_path.exists()
                
                # Append the information to the list
                file_info.append({
                    'subject': subject_dir.name,
                    'edf_file': file.name,
                    'event_file': event_file,
                    'event_exists': event_exists,
                    'edf_path': str(file.resolve()),
                    'event_path': str(event_path.resolve()) if event_exists else None
                })

# Convert the list to a DataFrame for better visualization
df_files = pd.DataFrame(file_info)

# Display summary of processed subject directories
print(f"Total subject directories processed: {processed_subjects}")
# Out:
# Total subject directories processed: 109

# %%
# Total number of matched .edf files
total_edf = df_files.shape[0]

# Number of event files present
total_events = df_files['event_exists'].sum()

# Number of missing event files
missing_events = total_edf - total_events

print(f"Total matched .edf files: {total_edf}")
print(f"Number of corresponding event files found: {total_events}")
print(f"Number of missing event files: {missing_events}")
# Out:
# Total matched .edf files: 327
# Number of corresponding event files found: 327
# Number of missing event files: 0

# %%
# Filter the DataFrame for missing event files
df_missing_events = df_files[~df_files['event_exists']]

# Display the list of .edf files without corresponding event files
if not df_missing_events.empty:
    print("\nFiles missing corresponding event files:")
    display(df_missing_events[['subject', 'edf_file', 'event_file']])
else:
    print("\nAll matched .edf files have corresponding event files.")
# Out:
# All matched .edf files have corresponding event files.

# %%
# Display the entire DataFrame of matched files
print("List of All Matched .edf Files:")
display(df_files[['subject', 'edf_file', 'event_file', 'event_exists']])
# Out:
# List of All Matched .edf Files:
#     subject     edf_file         event_file  event_exists
# 0      S038  S038R12.edf  S038R12.edf.event          True
# 1      S038  S038R04.edf  S038R04.edf.event          True
# 2      S038  S038R08.edf  S038R08.edf.event          True
# 3      S007  S007R08.edf  S007R08.edf.event          True
# 4      S007  S007R04.edf  S007R04.edf.event          True
# ..      ...          ...                ...           ...
# 322    S106  S106R04.edf  S106R04.edf.event          True
# 323    S106  S106R08.edf  S106R08.edf.event          True
# 324    S108  S108R04.edf  S108R04.edf.event          True
# 325    S108  S108R12.edf  S108R12.edf.event          True
# 326    S108  S108R08.edf  S108R08.edf.event          True
#
# [327 rows x 4 columns]

# %%
# Initialize lists to collect data and labels from all files
X_all = []
y_all = []

# %%
# Assuming df_files is already created as per your initial code









# Define your desired event types
desired_event_types = ['Rest', 'Imagining Left Hand', 'Imagining Right Hand']

# Iterate through each matched EDF file
for idx, row in df_files.iterrows():
    edf_path = row['edf_path']
    event_exists = row['event_exists']
    subject = row['subject']
    edf_file = row['edf_file']
    
    print(f"\nProcessing file: {edf_file} for subject: {subject}")
    
    if not event_exists:
        print(f"Skipping {edf_file} as it lacks an event file.")
        continue
    
    try:
        # Load the raw EEG data

        raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
        # Convert annotations to events and event_id
        events, event_id = mne.events_from_annotations(raw) # This line is missing in your code

        # Define event dictionary
        event_dict = {
            'Rest': 1,                # T0
            'Imagining Left Hand': 2,  # T1
            'Imagining Right Hand': 3  # T2
        }



        # Update event_id with descriptive labels
        event_id = {
            'Rest': 1,
            'Imagining Left Hand': 2,
            'Imagining Right Hand': 3
        }

        
        # Access annotations
        annotations = raw.annotations
        
        # Define epoch parameters
        tmin = -0.2  # 200 ms before the event
        tmax = 3.8   # 3800 ms after the event
        baseline = (None, 0)  # Baseline correction
        
        # Convert annotations to events
        events, _ = mne.events_from_annotations(raw, event_id=event_dict)
        
        if events.size == 0:
            print(f"No events found in {edf_file}. Skipping.")
            continue
        
        # Create epochs
        epochs = Epochs(raw, events, event_id=event_dict, tmin=tmin, tmax=tmax, baseline=baseline, preload=True, verbose=False)
        
        # Select only 'Imagining Left Hand' and 'Imagining Right Hand' epochs
        motor_epochs = epochs[['Imagining Left Hand', 'Imagining Right Hand']]
        
        if len(motor_epochs) == 0:
            print(f"No motor-related epochs found in {edf_file}. Skipping.")
            continue
        
        # Extract labels: 0 for Left, 1 for Right
        labels = motor_epochs.events[:, -1] - event_dict['Imagining Left Hand']
        
        # Get the data as a NumPy array: shape (n_epochs, n_channels, n_times)
        X = motor_epochs.get_data()
        y = labels
        
        # Append to the aggregate lists
        X_all.append(X)
        y_all.append(y)
        
        print(f"Loaded {X.shape[0]} epochs from {edf_file}.")
        
    except Exception as e:
        print(f"Failed to process {edf_file}. Error: {e}")


'''
# Define the path to the EDF file
edf_file = '../data/raw data/S001/S001R04.edf'

# Load the raw EEG data
raw = mne.io.read_raw_edf(edf_file, preload=True)

# Display basic information about the loaded data
print(raw.info)

# Plot raw EEG data interactively (optional)
# raw.plot(duration=30, n_channels=30, scalings='auto', title='Raw EEG Signals', show=True)

# Load the raw EEG data with annotations
raw = mne.io.read_raw_edf(edf_file, preload=True)

# Access annotations
annotations = raw.annotations

# Display annotations
print(annotations)

# Define event dictionary
event_dict = {
    'Rest': 1,                # T0
    'Imagining Left Hand': 2,  # T1
    'Imagining Right Hand': 3  # T2
}

# Convert annotations to events and event_id
events, event_id = mne.events_from_annotations(raw)

# Update event_id with descriptive labels
event_id = {
    'Rest': 1,
    'Imagining Left Hand': 2,
    'Imagining Right Hand': 3
}

print(event_id)

from mne import Epochs

# Define epoch parameters
tmin = -0.2  # 200 ms before the event
tmax = 3.8   # 3800 ms after the event
baseline = (None, 0)  # Baseline correction

# Create epochs
epochs = Epochs(raw, events, event_id=event_id, tmin=tmin, tmax=tmax, baseline=baseline, preload=True)

# Display epoch information
print(epochs)

# Plot an average epoch for 'Imagining Left Hand' (optional)
# fig = epochs['Imagining Left Hand'].average().plot()
# fig.suptitle('Imagining Left Hand')
# plt.show()

# Plot an average epoch for 'Imagining Right Hand' (optional)
# fig = epochs['Imagining Right Hand'].average().plot()
# fig.suptitle('Imagining Right Hand')
# plt.show()

# Plot an average epoch for 'Rest' (optional)
# fig = epochs['Rest'].average().plot()
# fig.suptitle('Rest')
# plt.show()

# Select only 'Imagining Left Hand' and 'Imagining Right Hand' epochs
motor_epochs = epochs[['Imagining Left Hand', 'Imagining Right Hand']]

# Extract labels: 0 for Left, 1 for Right
labels = motor_epochs.events[:, -1] - 2  # 'Imagining Left Hand' = 2, 'Imagining Right Hand' = 3

# Verify the distribution of classes
print("Class distribution:", np.bincount(labels))

# Get the data as a NumPy array: shape (n_epochs, n_channels, n_times)
X = motor_epochs.get_data()
y = labels

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
'''
# Out:
# Processing file: S038R12.edf for subject: S038
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S038R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S038R04.edf for subject: S038
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S038R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S038R08.edf for subject: S038
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S038R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S007R08.edf for subject: S007
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S007R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S007R04.edf for subject: S007
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S007R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S007R12.edf for subject: S007
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S007R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S031R08.edf for subject: S031
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S031R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S031R04.edf for subject: S031
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S031R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S031R12.edf for subject: S031
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S031R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S009R08.edf for subject: S009
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S009R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S009R12.edf for subject: S009
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S009R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S009R04.edf for subject: S009
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S009R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S036R04.edf for subject: S036
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S036R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S036R12.edf for subject: S036
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S036R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S036R08.edf for subject: S036
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S036R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S096R04.edf for subject: S096
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S096R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S096R12.edf for subject: S096
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S096R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S096R08.edf for subject: S096
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S096R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S062R08.edf for subject: S062
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S062R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S062R12.edf for subject: S062
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S062R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S062R04.edf for subject: S062
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S062R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S065R12.edf for subject: S065
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S065R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S065R04.edf for subject: S065
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S065R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S065R08.edf for subject: S065
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S065R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S091R08.edf for subject: S091
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S091R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S091R04.edf for subject: S091
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S091R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S091R12.edf for subject: S091
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S091R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S053R12.edf for subject: S053
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S053R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S053R04.edf for subject: S053
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S053R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S053R08.edf for subject: S053
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S053R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S098R12.edf for subject: S098
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S098R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S098R04.edf for subject: S098
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S098R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S098R08.edf for subject: S098
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S098R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S054R08.edf for subject: S054
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S054R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S054R12.edf for subject: S054
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S054R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S054R04.edf for subject: S054
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S054R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S008R04.edf for subject: S008
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S008R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S008R12.edf for subject: S008
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S008R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S008R08.edf for subject: S008
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S008R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S037R08.edf for subject: S037
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S037R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S037R12.edf for subject: S037
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S037R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S037R04.edf for subject: S037
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S037R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S030R12.edf for subject: S030
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S030R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S030R04.edf for subject: S030
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S030R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S030R08.edf for subject: S030
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S030R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S039R08.edf for subject: S039
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S039R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S039R04.edf for subject: S039
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S039R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S039R12.edf for subject: S039
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S039R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S006R12.edf for subject: S006
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S006R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S006R04.edf for subject: S006
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S006R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S006R08.edf for subject: S006
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S006R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S001R08.edf for subject: S001
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S001R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S001R12.edf for subject: S001
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S001R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S001R04.edf for subject: S001
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S001R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S055R04.edf for subject: S055
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S055R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S055R12.edf for subject: S055
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S055R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S055R08.edf for subject: S055
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S055R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S052R08.edf for subject: S052
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S052R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S052R04.edf for subject: S052
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S052R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S052R12.edf for subject: S052
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S052R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S099R08.edf for subject: S099
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S099R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S099R04.edf for subject: S099
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S099R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S099R12.edf for subject: S099
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S099R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S090R12.edf for subject: S090
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S090R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S090R04.edf for subject: S090
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S090R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S090R08.edf for subject: S090
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S090R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S064R08.edf for subject: S064
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S064R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S064R04.edf for subject: S064
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S064R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S064R12.edf for subject: S064
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S064R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S063R04.edf for subject: S063
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S063R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S063R12.edf for subject: S063
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S063R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S063R08.edf for subject: S063
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S063R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S097R08.edf for subject: S097
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S097R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S097R12.edf for subject: S097
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S097R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S097R04.edf for subject: S097
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S097R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S041R12.edf for subject: S041
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S041R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S041R04.edf for subject: S041
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S041R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S041R08.edf for subject: S041
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S041R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S079R04.edf for subject: S079
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S079R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S079R12.edf for subject: S079
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S079R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S079R08.edf for subject: S079
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S079R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S046R08.edf for subject: S046
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S046R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S046R12.edf for subject: S046
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S046R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S046R04.edf for subject: S046
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S046R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S084R04.edf for subject: S084
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S084R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S084R12.edf for subject: S084
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S084R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S084R08.edf for subject: S084
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S084R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S070R08.edf for subject: S070
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S070R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S070R12.edf for subject: S070
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S070R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S070R04.edf for subject: S070
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S070R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S048R08.edf for subject: S048
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S048R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S048R04.edf for subject: S048
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S048R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S048R12.edf for subject: S048
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S048R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S077R12.edf for subject: S077
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S077R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S077R04.edf for subject: S077
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S077R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S077R08.edf for subject: S077
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S077R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S083R08.edf for subject: S083
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S083R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S083R04.edf for subject: S083
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S083R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S083R12.edf for subject: S083
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S083R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S023R08.edf for subject: S023
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S023R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S023R04.edf for subject: S023
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S023R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S023R12.edf for subject: S023
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S023R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S024R04.edf for subject: S024
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S024R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S024R12.edf for subject: S024
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S024R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S024R08.edf for subject: S024
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S024R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S012R04.edf for subject: S012
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S012R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S012R12.edf for subject: S012
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S012R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S012R08.edf for subject: S012
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S012R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S015R08.edf for subject: S015
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S015R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S015R04.edf for subject: S015
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S015R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S015R12.edf for subject: S015
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S015R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S049R12.edf for subject: S049
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S049R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S049R04.edf for subject: S049
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S049R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S049R08.edf for subject: S049
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S049R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S082R12.edf for subject: S082
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S082R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S082R04.edf for subject: S082
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S082R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S082R08.edf for subject: S082
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S082R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S076R08.edf for subject: S076
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S076R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S076R04.edf for subject: S076
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S076R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S076R12.edf for subject: S076
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S076R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S071R04.edf for subject: S071
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S071R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S071R12.edf for subject: S071
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S071R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S071R08.edf for subject: S071
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S071R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S085R08.edf for subject: S085
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S085R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S085R12.edf for subject: S085
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S085R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S085R04.edf for subject: S085
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S085R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S078R08.edf for subject: S078
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S078R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S078R12.edf for subject: S078
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S078R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S078R04.edf for subject: S078
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S078R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S047R04.edf for subject: S047
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S047R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S047R12.edf for subject: S047
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S047R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S047R08.edf for subject: S047
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S047R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S040R08.edf for subject: S040
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S040R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S040R04.edf for subject: S040
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S040R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S040R12.edf for subject: S040
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S040R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S014R12.edf for subject: S014
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S014R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S014R04.edf for subject: S014
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S014R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S014R08.edf for subject: S014
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S014R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S013R08.edf for subject: S013
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S013R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S013R12.edf for subject: S013
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S013R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S013R04.edf for subject: S013
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S013R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S025R08.edf for subject: S025
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S025R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S025R12.edf for subject: S025
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S025R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S025R04.edf for subject: S025
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S025R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S022R12.edf for subject: S022
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S022R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S022R04.edf for subject: S022
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S022R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S022R08.edf for subject: S022
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S022R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S103R08.edf for subject: S103
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S103R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S103R04.edf for subject: S103
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S103R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S103R12.edf for subject: S103
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S103R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S104R04.edf for subject: S104
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S104R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S104R12.edf for subject: S104
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S104R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S104R08.edf for subject: S104
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S104R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S105R08.edf for subject: S105
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S105R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S105R12.edf for subject: S105
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S105R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S105R04.edf for subject: S105
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S105R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S102R12.edf for subject: S102
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S102R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S102R04.edf for subject: S102
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S102R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S102R08.edf for subject: S102
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S102R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S066R08.edf for subject: S066
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S066R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S066R12.edf for subject: S066
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S066R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S066R04.edf for subject: S066
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S066R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S092R04.edf for subject: S092
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S092R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S092R12.edf for subject: S092
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S092R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S092R08.edf for subject: S092
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S092R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S059R04.edf for subject: S059
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S059R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S059R12.edf for subject: S059
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S059R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S059R08.edf for subject: S059
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S059R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S095R08.edf for subject: S095
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S095R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S095R04.edf for subject: S095
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S095R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S095R12.edf for subject: S095
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S095R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S061R12.edf for subject: S061
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S061R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S061R04.edf for subject: S061
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S061R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S061R08.edf for subject: S061
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S061R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S057R12.edf for subject: S057
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S057R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S057R04.edf for subject: S057
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S057R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S057R08.edf for subject: S057
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S057R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S068R08.edf for subject: S068
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S068R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S068R04.edf for subject: S068
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S068R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S068R12.edf for subject: S068
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S068R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S050R08.edf for subject: S050
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S050R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S050R12.edf for subject: S050
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S050R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S050R04.edf for subject: S050
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S050R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S004R04.edf for subject: S004
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S004R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S004R12.edf for subject: S004
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S004R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S004R08.edf for subject: S004
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S004R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S003R08.edf for subject: S003
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S003R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S003R04.edf for subject: S003
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S003R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S003R12.edf for subject: S003
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S003R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S035R08.edf for subject: S035
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S035R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S035R04.edf for subject: S035
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S035R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S035R12.edf for subject: S035
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S035R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S032R04.edf for subject: S032
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S032R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S032R12.edf for subject: S032
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S032R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S032R08.edf for subject: S032
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S032R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S051R04.edf for subject: S051
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S051R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S051R12.edf for subject: S051
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S051R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S051R08.edf for subject: S051
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S051R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S056R08.edf for subject: S056
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S056R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S056R04.edf for subject: S056
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S056R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S056R12.edf for subject: S056
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S056R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S069R12.edf for subject: S069
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S069R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S069R04.edf for subject: S069
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S069R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S069R08.edf for subject: S069
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S069R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S060R08.edf for subject: S060
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S060R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S060R04.edf for subject: S060
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S060R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S060R12.edf for subject: S060
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S060R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S094R12.edf for subject: S094
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S094R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S094R04.edf for subject: S094
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S094R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S094R08.edf for subject: S094
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S094R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S093R08.edf for subject: S093
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S093R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S093R12.edf for subject: S093
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S093R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S093R04.edf for subject: S093
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S093R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S067R04.edf for subject: S067
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S067R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S067R12.edf for subject: S067
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S067R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S067R08.edf for subject: S067
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S067R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S058R08.edf for subject: S058
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S058R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S058R12.edf for subject: S058
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S058R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S058R04.edf for subject: S058
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S058R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S033R08.edf for subject: S033
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S033R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S033R12.edf for subject: S033
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S033R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S033R04.edf for subject: S033
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S033R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S034R12.edf for subject: S034
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S034R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S034R04.edf for subject: S034
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S034R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S034R08.edf for subject: S034
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S034R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S002R12.edf for subject: S002
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S002R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S002R04.edf for subject: S002
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S002R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S002R08.edf for subject: S002
# ...
#
# Processing file: S087R12.edf for subject: S087
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S087R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S073R12.edf for subject: S073
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S073R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S073R04.edf for subject: S073
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S073R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S073R08.edf for subject: S073
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S073R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S010R12.edf for subject: S010
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S010R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S010R04.edf for subject: S010
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S010R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S010R08.edf for subject: S010
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S010R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S017R08.edf for subject: S017
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S017R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S017R12.edf for subject: S017
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S017R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S017R04.edf for subject: S017
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S017R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S028R04.edf for subject: S028
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S028R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S028R12.edf for subject: S028
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S028R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S028R08.edf for subject: S028
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S028R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S021R08.edf for subject: S021
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S021R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S021R12.edf for subject: S021
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S021R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S021R04.edf for subject: S021
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S021R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S026R12.edf for subject: S026
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S026R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S026R04.edf for subject: S026
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S026R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S026R08.edf for subject: S026
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S026R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S019R08.edf for subject: S019
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S019R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S019R04.edf for subject: S019
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S019R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S019R12.edf for subject: S019
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S019R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S072R08.edf for subject: S072
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S072R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S072R04.edf for subject: S072
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S072R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S072R12.edf for subject: S072
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S072R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S086R12.edf for subject: S086
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S086R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S086R04.edf for subject: S086
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S086R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S086R08.edf for subject: S086
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S086R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S081R08.edf for subject: S081
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S081R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S081R12.edf for subject: S081
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S081R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S081R04.edf for subject: S081
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S081R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S075R04.edf for subject: S075
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S075R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S075R12.edf for subject: S075
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S075R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S075R08.edf for subject: S075
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S075R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S088R04.edf for subject: S088
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S088R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S088R12.edf for subject: S088
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S088R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S088R08.edf for subject: S088
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S088R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S043R04.edf for subject: S043
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S043R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S043R12.edf for subject: S043
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S043R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S043R08.edf for subject: S043
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S043R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S044R08.edf for subject: S044
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S044R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S044R04.edf for subject: S044
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S044R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S044R12.edf for subject: S044
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S044R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S109R08.edf for subject: S109
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S109R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S109R12.edf for subject: S109
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S109R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S109R04.edf for subject: S109
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S109R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S107R08.edf for subject: S107
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S107R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S107R04.edf for subject: S107
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S107R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S107R12.edf for subject: S107
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S107R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S100R04.edf for subject: S100
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S100R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S100R12.edf for subject: S100
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S100R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S100R08.edf for subject: S100
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S100R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S101R08.edf for subject: S101
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S101R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S101R12.edf for subject: S101
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S101R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S101R04.edf for subject: S101
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S101R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S106R12.edf for subject: S106
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S106R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S106R04.edf for subject: S106
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S106R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S106R08.edf for subject: S106
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S106R08.edf. Error: Could not find any of the events you specified.
#
# Processing file: S108R04.edf for subject: S108
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S108R04.edf. Error: Could not find any of the events you specified.
#
# Processing file: S108R12.edf for subject: S108
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S108R12.edf. Error: Could not find any of the events you specified.
#
# Processing file: S108R08.edf for subject: S108
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Failed to process S108R08.edf. Error: Could not find any of the events you specified.
# /var/folders/64/t0s5x1395f38bgfnfwy0_cdh0000gn/T/ipykernel_75021/692152130.py:30: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /var/folders/64/t0s5x1395f38bgfnfwy0_cdh0000gn/T/ipykernel_75021/692152130.py:30: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# /var/folders/64/t0s5x1395f38bgfnfwy0_cdh0000gn/T/ipykernel_75021/692152130.py:30: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
# '\n# Define the path to the EDF file\nedf_file = \'../data/raw data/S001/S001R04.edf\'\n\n# Load the raw EEG data\nraw = mne.io.read_raw_edf(edf_file, preload=True)\n\n# Display basic information about the loaded data\nprint(raw.info)\n\n# Plot raw EEG data interactively (optional)\n# raw.plot(duration=30, n_channels=30, scalings=\'auto\', title=\'Raw EEG Signals\', show=True)\n\n# Load the raw EEG data with annotations\nraw = mne.io.read_raw_edf(edf_file, preload=True)\n\n# Access annotations\nannotations = raw.annotations\n\n# Display annotations\nprint(annotations)\n\n# Define event dictionary\nevent_dict = {\n    \'Rest\': 1,                # T0\n    \'Imagining Left Hand\': 2,  # T1\n    \'Imagining Right Hand\': 3  # T2\n}\n\n# Convert annotations to events and event_id\nevents, event_id = mne.events_from_annotations(raw)\n\n# Update event_id with descriptive labels\nevent_id = {\n    \'Rest\': 1,\n    \'Imagining Left Hand\': 2,\n    \'Imagining Right Hand\': 3\n}\n\nprint(event_id)\n\nfrom mne import Epochs\n\n# Define epoch parameters\ntmin = -0.2  # 200 ms before the event\ntmax = 3.8   # 3800 ms after the event\nbaseline = (None, 0)  # Baseline correction\n\n# Create epochs\nepochs = Epochs(raw, events, event_id=event_id, tmin=tmin, tmax=tmax, baseline=baseline, preload=True)\n\n# Display epoch information\nprint(epochs)\n\n# Plot an average epoch for \'Imagining Left Hand\' (optional)\n# fig = epochs[\'Imagining Left Hand\'].average().plot()\n# fig.suptitle(\'Imagining Left Hand\')\n# plt.show()\n\n# Plot an average epoch for \'Imagining Right Hand\' (optional)\n# fig = epochs[\'Imagining Right Hand\'].average().plot()\n# fig.suptitle(\'Imagining Right Hand\')\n# plt.show()\n\n# Plot an average epoch for \'Rest\' (optional)\n# fig = epochs[\'Rest\'].average().plot()\n# fig.suptitle(\'Rest\')\n# plt.show()\n\n# Select only \'Imagining Left Hand\' and \'Imagining Right Hand\' epochs\nmotor_epochs = epochs[[\'Imagining Left Hand\', \'Imagining Right Hand\']]\n\n# Extract labels: 0 for Left, 1 for Right\nlabels = motor_epochs.events[:, -1] - 2  # \'Imagining Left Hand\' = 2, \'Imagining Right Hand\' = 3\n\n# Verify the distribution of classes\nprint("Class distribution:", np.bincount(labels))\n\n# Get the data as a NumPy array: shape (n_epochs, n_channels, n_times)\nX = motor_epochs.get_data()\ny = labels\n\nprint(f"Shape of X: {X.shape}")\nprint(f"Shape of y: {y.shape}")\n'

# %%
# Concatenate all epochs and labels
if X_all and y_all:
    X_all = np.concatenate(X_all, axis=0)
    y_all = np.concatenate(y_all, axis=0)
    
    print(f"\nTotal epochs collected: {X_all.shape[0]}")
    print(f"Shape of X_all: {X_all.shape}")
    print(f"Shape of y_all: {y_all.shape}")
else:
    raise ValueError("No epochs were loaded. Please check your EDF files and event annotations.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 10
#       8     print(f"Shape of y_all: {y_all.shape}")
#       9 else:
# ---> 10     raise ValueError("No epochs were loaded. Please check your EDF files and event annotations.")
#
# ValueError: No epochs were loaded. Please check your EDF files and event annotations.

# %%
# Define frequency bands (in Hz)
freq_bands = [
    (8, 12),    # Alpha
    (13, 20),   # Beta 1
    (21, 30),   # Beta 2
    (31, 40),   # Low Gamma
    (41, 50),   # High Gamma
    (51, 60),   # Very High Gamma
    (61, 70),   # Ultra High Gamma
    (71, 79)    # Max Gamma
]

# %%
class FBCSP(BaseEstimator, TransformerMixin):
    def __init__(self, freq_bands, n_csp=4, sfreq=160):
        """
        Initialize the FBCSP transformer.
        
        Parameters:
        - freq_bands: List of tuples defining frequency bands.
        - n_csp: Number of CSP components per band.
        - sfreq: Sampling frequency of the EEG data.
        """
        self.freq_bands = freq_bands
        self.n_csp = n_csp
        self.sfreq = sfreq
        self.csp_list_ = []  # To store CSP models for each band

    def fit(self, X, y):
        """
        Fit CSP models for each frequency band.
        
        Parameters:
        - X: EEG data, shape (n_trials, n_channels, n_times)
        - y: Labels, shape (n_trials,)
        
        Returns:
        - self
        """
        self.csp_list_ = []  # Reset in case of multiple fits
        for band in self.freq_bands:
            print(f'Fitting CSP for band: {band[0]}-{band[1]} Hz')
            # Band-pass filter the data for the current frequency band
            X_filtered = np.array([
                filter_data(trial, sfreq=self.sfreq, l_freq=band[0], h_freq=band[1], method='iir', verbose=False)
                for trial in X
            ])
            
            # Initialize and fit CSP
            csp = CSP(n_components=self.n_csp, reg=None, log=True, norm_trace=False)
            csp.fit(X_filtered, y)
            self.csp_list_.append(csp)
        return self

    def transform(self, X):
        """
        Transform EEG data using the fitted CSP models.
        
        Parameters:
        - X: EEG data, shape (n_trials, n_channels, n_times)
        
        Returns:
        - X_features: Extracted features, shape (n_trials, n_bands * n_csp)
        """
        features = []
        for idx, band in enumerate(self.freq_bands):
            print(f'Transforming data for band: {band[0]}-{band[1]} Hz')
            csp = self.csp_list_[idx]
            # Band-pass filter the data for the current frequency band
            X_filtered = np.array([
                filter_data(trial, sfreq=self.sfreq, l_freq=band[0], h_freq=band[1], method='iir', verbose=False)
                for trial in X
            ])
            
            # Apply CSP transformation
            X_csp = csp.transform(X_filtered)
            
            # Extract log-variance features
            X_logvar = np.log(np.var(X_csp, axis=1))
            
            # Reshape X_logvar to (n_trials, 1) to make it 2D
            X_logvar = X_logvar.reshape(-1, 1)
            
            # Append the reshaped feature
            features.append(X_logvar)
        
        # Concatenate features from all bands along axis=1
       
        X_features = np.column_stack(features)
        return X_features

# %%
# Initialize FBCSP transformer
fbcsp = FBCSP(freq_bands=freq_bands, n_csp=4, sfreq=160)  # Replace sfreq with your actual sampling frequency

# Initialize Neural Network classifier
mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)

# Define the classification pipeline
pipeline = Pipeline([
    ('fbcsp', fbcsp),
    ('classifier', mlp)
])

# %%
# Define cross-validation strategy
n_splits = 5  # Adjust based on your dataset size
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Perform cross-validation
print("Starting Cross-Validation...")
scores = cross_val_score(pipeline, X, y, cv=cv, scoring='accuracy')

print(f"\nCross-Validation Accuracy Scores: {scores}")
print(f"Mean Accuracy: {scores.mean() * 100:.2f}%")
print(f"Standard Deviation: {scores.std() * 100:.2f}%")
# Out:
# Starting Cross-Validation...
# Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.6e-05 (2.2e-16 eps * 64 dim * 6.1e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.2e-05 (2.2e-16 eps * 64 dim * 5.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 5.5e-05 (2.2e-16 eps * 64 dim * 3.9e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.5e-05 (2.2e-16 eps * 64 dim * 2.5e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.2e-05 (2.2e-16 eps * 64 dim * 2.2e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 2.5e-05 (2.2e-16 eps * 64 dim * 1.7e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.7e-05 (2.2e-16 eps * 64 dim * 1.2e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 64 dim * 7.8e+08  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# /Users/helechuan/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.6e-05 (2.2e-16 eps * 64 dim * 6.1e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.1e-05 (2.2e-16 eps * 64 dim * 5.7e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 5.4e-05 (2.2e-16 eps * 64 dim * 3.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.7e-05 (2.2e-16 eps * 64 dim * 2.6e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.3e-05 (2.2e-16 eps * 64 dim * 2.3e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 2.5e-05 (2.2e-16 eps * 64 dim * 1.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.7e-05 (2.2e-16 eps * 64 dim * 1.2e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 64 dim * 7.8e+08  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# /Users/helechuan/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.6e-05 (2.2e-16 eps * 64 dim * 6e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 7.9e-05 (2.2e-16 eps * 64 dim * 5.5e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 5.5e-05 (2.2e-16 eps * 64 dim * 3.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.7e-05 (2.2e-16 eps * 64 dim * 2.6e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.3e-05 (2.2e-16 eps * 64 dim * 2.3e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 2.5e-05 (2.2e-16 eps * 64 dim * 1.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.8e-05 (2.2e-16 eps * 64 dim * 1.2e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 64 dim * 8e+08  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.5e-05 (2.2e-16 eps * 64 dim * 6e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.2e-05 (2.2e-16 eps * 64 dim * 5.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 5.4e-05 (2.2e-16 eps * 64 dim * 3.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.6e-05 (2.2e-16 eps * 64 dim * 2.5e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.3e-05 (2.2e-16 eps * 64 dim * 2.3e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 2.5e-05 (2.2e-16 eps * 64 dim * 1.7e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.7e-05 (2.2e-16 eps * 64 dim * 1.2e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 64 dim * 7.9e+08  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# /Users/helechuan/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Fitting CSP for band: 8-12 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.4e-05 (2.2e-16 eps * 64 dim * 5.9e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 13-20 Hz
# Computing rank from data with rank=None
#     Using tolerance 8.1e-05 (2.2e-16 eps * 64 dim * 5.7e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 21-30 Hz
# Computing rank from data with rank=None
#     Using tolerance 5.4e-05 (2.2e-16 eps * 64 dim * 3.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 31-40 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.8e-05 (2.2e-16 eps * 64 dim * 2.7e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 41-50 Hz
# Computing rank from data with rank=None
#     Using tolerance 3.3e-05 (2.2e-16 eps * 64 dim * 2.4e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 51-60 Hz
# Computing rank from data with rank=None
#     Using tolerance 2.6e-05 (2.2e-16 eps * 64 dim * 1.8e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 61-70 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.8e-05 (2.2e-16 eps * 64 dim * 1.2e+09  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Fitting CSP for band: 71-79 Hz
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 64 dim * 7.9e+08  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
# Transforming data for band: 8-12 Hz
# Transforming data for band: 13-20 Hz
# Transforming data for band: 21-30 Hz
# Transforming data for band: 31-40 Hz
# Transforming data for band: 41-50 Hz
# Transforming data for band: 51-60 Hz
# Transforming data for band: 61-70 Hz
# Transforming data for band: 71-79 Hz
#
# Cross-Validation Accuracy Scores: [0.33333333 0.33333333 1.         0.         0.66666667]
# Mean Accuracy: 46.67%
# Standard Deviation: 33.99%
# /Users/helechuan/Library/Mobile Documents/com~apple~CloudDocs/Documents/4th Year University/4th Year Project/64-Channels-EEG-Data-ML-training/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
